# %%
# %load_ext autoreload  
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ocpy.data import Data
# data okuma check

data = Data.from_file("xy_boo.xlsx")
data.data
# Out:
#      minimum_time  minimum_time_error  weights minimum_type labels
# 0    2.431215e+06            0.035894      NaN            P    vis
# 1    2.431216e+06            0.002838     30.0            S    vis
# 2    2.431219e+06            0.016068      NaN            S    vis
# 3    2.431221e+06            0.049011      NaN            P    vis
# 4    2.431225e+06            0.037684      NaN            P    vis
# ..            ...                 ...      ...          ...    ...
# 201  2.458945e+06            0.000603      NaN            S    -Ir
# 202  2.460466e+06            0.000935      NaN            P    ccd
# 203  2.460472e+06            0.008531      NaN            S    ccd
# 204  2.460796e+06            0.008955      NaN            S  Clear
# 205  2.460796e+06            0.009831      NaN            P  Clear
#
# [206 rows x 5 columns]

# %%
import numpy as np
DATA = Data(np.linspace(2460925.5, 2460935.5, 200).tolist())
oc = DATA.calculate_oc(
    float(np.mean(np.diff(DATA["minimum_time"]))),
    float(DATA[0]["minimum_time"]),
    
)
print(oc)
# Out:
#      minimum_time minimum_time_error weights minimum_type labels  cycle  \
# 0    2.460926e+06               None    None         None   None    1.0
# 1    2.460926e+06               None    None         None   None    1.0
# 2    2.460926e+06               None    None         None   None    1.0
# 3    2.460926e+06               None    None         None   None    1.0
# 4    2.460926e+06               None    None         None   None    1.0
# ..            ...                ...     ...          ...    ...    ...
# 195  2.460935e+06               None    None         None   None    1.0
# 196  2.460935e+06               None    None         None   None    1.0
# 197  2.460935e+06               None    None         None   None    1.0
# 198  2.460935e+06               None    None         None   None    1.0
# 199  2.460936e+06               None    None         None   None    1.0
#
#            oc
# 0   -0.050251
# 1    0.000000
# 2    0.050251
# 3    0.100503
# 4    0.150754
# ...

# %%
data = Data.from_file("xy_boo_difcol.xlsx", columns={"weights":"www", "minimum_type":"mt"})
data.data
# Out:
#      minimum_time  minimum_time_error  weights  minimum_type labels
# 0      31215.3860            0.029035      NaN             0    vis
# 1      31216.3400            0.049489     30.0             1    vis
# 2      31219.2600                 NaN      NaN             1    vis
# 3      31221.3300            0.038749      NaN             0    vis
# 4      31225.4000            0.011400      NaN             0    vis
# ..            ...                 ...      ...           ...    ...
# 192    57876.7248            0.001721      NaN             0    CCD
# 193    58244.6952            0.005465      NaN             0    CCD
# 194    58599.7012            0.009613      NaN             0    CCD
# 195    58618.4270            0.000834      NaN             1    CCD
# 196    58944.5259            0.006040      NaN             1    CCD
#
# [197 rows x 5 columns]

# %%
data = Data.from_file("xy_boo_difcol.csv", columns={"weights":"www", "minimum_type":"mt"})
data.data
# Out:
#      minimum_time  minimum_time_error  weights  minimum_type labels
# 0      31215.3860            0.029035      NaN             0    vis
# 1      31216.3400            0.049489     30.0             1    vis
# 2      31219.2600                 NaN      NaN             1    vis
# 3      31221.3300            0.038749      NaN             0    vis
# 4      31225.4000            0.011400      NaN             0    vis
# ..            ...                 ...      ...           ...    ...
# 192    57876.7248            0.001721      NaN             0    CCD
# 193    58244.6952            0.005465      NaN             0    CCD
# 194    58599.7012            0.009613      NaN             0    CCD
# 195    58618.4270            0.000834      NaN             1    CCD
# 196    58944.5259            0.006040      NaN             1    CCD
#
# [197 rows x 5 columns]

# %%
import numpy as np
data = Data.from_file("xy_boo.xlsx")
error_filled_data = data.fill_errors(errors=.3, override=False)
error_filled_data.data
# Out:
#      minimum_time  minimum_time_error  weights minimum_type labels
# 0    2.431215e+06            0.035894      NaN            P    vis
# 1    2.431216e+06            0.002838     30.0            S    vis
# 2    2.431219e+06            0.016068      NaN            S    vis
# 3    2.431221e+06            0.049011      NaN            P    vis
# 4    2.431225e+06            0.037684      NaN            P    vis
# ..            ...                 ...      ...          ...    ...
# 201  2.458945e+06            0.000603      NaN            S    -Ir
# 202  2.460466e+06            0.000935      NaN            P    ccd
# 203  2.460472e+06            0.008531      NaN            S    ccd
# 204  2.460796e+06            0.008955      NaN            S  Clear
# 205  2.460796e+06            0.009831      NaN            P  Clear
#
# [206 rows x 5 columns]

# %%
data = Data.from_file("xy_boo.xlsx")
error_filled_data = data.fill_errors(errors=3, override=True)
error_filled_data.data
# Out:
#      minimum_time  minimum_time_error  weights minimum_type labels
# 0    2.431215e+06                   3      NaN            P    vis
# 1    2.431216e+06                   3     30.0            S    vis
# 2    2.431219e+06                   3      NaN            S    vis
# 3    2.431221e+06                   3      NaN            P    vis
# 4    2.431225e+06                   3      NaN            P    vis
# ..            ...                 ...      ...          ...    ...
# 201  2.458945e+06                   3      NaN            S    -Ir
# 202  2.460466e+06                   3      NaN            P    ccd
# 203  2.460472e+06                   3      NaN            S    ccd
# 204  2.460796e+06                   3      NaN            S  Clear
# 205  2.460796e+06                   3      NaN            P  Clear
#
# [206 rows x 5 columns]

# %%
data = Data.from_file("xy_boo.xlsx")
rng = np.random.default_rng()  
arr = rng.uniform(1, 3, size=206)
error_filled_data = data.fill_errors(errors=arr, override=False)
error_filled_data.data
# Out:
#      minimum_time  minimum_time_error  weights minimum_type labels
# 0    2.431215e+06            0.035894      NaN            P    vis
# 1    2.431216e+06            0.002838     30.0            S    vis
# 2    2.431219e+06            0.016068      NaN            S    vis
# 3    2.431221e+06            0.049011      NaN            P    vis
# 4    2.431225e+06            0.037684      NaN            P    vis
# ..            ...                 ...      ...          ...    ...
# 201  2.458945e+06            0.000603      NaN            S    -Ir
# 202  2.460466e+06            0.000935      NaN            P    ccd
# 203  2.460472e+06            0.008531      NaN            S    ccd
# 204  2.460796e+06            0.008955      NaN            S  Clear
# 205  2.460796e+06            0.009831      NaN            P  Clear
#
# [206 rows x 5 columns]

# %%
data = Data.from_file("xy_boo.xlsx")
rng = np.random.default_rng()  
arr = rng.uniform(1, 3, size=206)
error_filled_data = data.fill_errors(errors=arr, override=True)
error_filled_data.data
# Out:
#      minimum_time  minimum_time_error  weights minimum_type labels
# 0    2.431215e+06            2.769752      NaN            P    vis
# 1    2.431216e+06            2.107671     30.0            S    vis
# 2    2.431219e+06            2.329137      NaN            S    vis
# 3    2.431221e+06            2.680113      NaN            P    vis
# 4    2.431225e+06            2.820229      NaN            P    vis
# ..            ...                 ...      ...          ...    ...
# 201  2.458945e+06            1.809992      NaN            S    -Ir
# 202  2.460466e+06            1.497922      NaN            P    ccd
# 203  2.460472e+06            1.960715      NaN            S    ccd
# 204  2.460796e+06            2.217856      NaN            S  Clear
# 205  2.460796e+06            2.377312      NaN            P  Clear
#
# [206 rows x 5 columns]

# %%
# direkt weight verme check
data = Data.from_file("xy_boo.xlsx")
data = data.fill_weights(weights=3)
data.data
# Out:
#      minimum_time  minimum_time_error  weights minimum_type labels
# 0    2.431215e+06            0.035894      3.0            P    vis
# 1    2.431216e+06            0.002838     30.0            S    vis
# 2    2.431219e+06            0.016068      3.0            S    vis
# 3    2.431221e+06            0.049011      3.0            P    vis
# 4    2.431225e+06            0.037684      3.0            P    vis
# ..            ...                 ...      ...          ...    ...
# 201  2.458945e+06            0.000603      3.0            S    -Ir
# 202  2.460466e+06            0.000935      3.0            P    ccd
# 203  2.460472e+06            0.008531      3.0            S    ccd
# 204  2.460796e+06            0.008955      3.0            S  Clear
# 205  2.460796e+06            0.009831      3.0            P  Clear
#
# [206 rows x 5 columns]

# %%
data = Data.from_file("xy_boo.xlsx")
data = data.fill_weights(weights=3, override=True)
data.data
# Out:
#      minimum_time  minimum_time_error  weights minimum_type labels
# 0    2.431215e+06            0.035894        3            P    vis
# 1    2.431216e+06            0.002838        3            S    vis
# 2    2.431219e+06            0.016068        3            S    vis
# 3    2.431221e+06            0.049011        3            P    vis
# 4    2.431225e+06            0.037684        3            P    vis
# ..            ...                 ...      ...          ...    ...
# 201  2.458945e+06            0.000603        3            S    -Ir
# 202  2.460466e+06            0.000935        3            P    ccd
# 203  2.460472e+06            0.008531        3            S    ccd
# 204  2.460796e+06            0.008955        3            S  Clear
# 205  2.460796e+06            0.009831        3            P  Clear
#
# [206 rows x 5 columns]

# %%
# data = Data.from_file("xy_boo.xlsx")
# data = data.calculate_weights()
# data.data

# %%
data = Data.from_file("xy_boo.xlsx")
def new_f(errors: np._typing.NDArray):
    weights = errors
    return weights
data = data.calculate_weights(method=new_f)
data.data
# Out:
#      minimum_time  minimum_time_error   weights minimum_type labels
# 0    2.431215e+06            0.035894  0.035894            P    vis
# 1    2.431216e+06            0.002838  0.002838            S    vis
# 2    2.431219e+06            0.016068  0.016068            S    vis
# 3    2.431221e+06            0.049011  0.049011            P    vis
# 4    2.431225e+06            0.037684  0.037684            P    vis
# ..            ...                 ...       ...          ...    ...
# 201  2.458945e+06            0.000603  0.000603            S    -Ir
# 202  2.460466e+06            0.000935  0.000935            P    ccd
# 203  2.460472e+06            0.008531  0.008531            S    ccd
# 204  2.460796e+06            0.008955  0.008955            S  Clear
# 205  2.460796e+06            0.009831  0.009831            P  Clear
#
# [206 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
data = data.calculate_oc(reference_minimum=39954.025, reference_period=0.370564)
plt.plot(data["cycle"], data["oc"], ".r")

# %%
data = Data.from_file("xy_boo.xlsx")
data = data.calculate_oc(reference_minimum=39954.025, reference_period=0.370564)
import pandas as pd
data.data["bin"] = pd.cut(data.data["cycle"], bins=20)
data.data["bin"]
# Out:
# 0      (6452952.173, 6457023.35]
# 1      (6452952.173, 6457023.35]
# 2      (6452952.173, 6457023.35]
# 3      (6452952.173, 6457023.35]
# 4      (6452952.173, 6457023.35]
#                  ...
# 201      (6524876.3, 6528867.65]
# 202      (6528867.65, 6532859.0]
# 203      (6528867.65, 6532859.0]
# 204      (6528867.65, 6532859.0]
# 205      (6528867.65, 6532859.0]
# Name: bin, Length: 206, dtype: category
# Categories (20, interval[float64, right]): [(6452952.173, 6457023.35] < (6457023.35, 6461014.7] < (6461014.7, 6465006.05] < (6465006.05, 6468997.4] ... (6516893.6, 6520884.95] < (6520884.95, 6524876.3] < (6524876.3, 6528867.65] < (6528867.65, 6532859.0]]

# %%
data = Data(np.linspace(2460925.5, 2460935.5, 200).tolist())
oc = data.calculate_oc(
    float(np.mean(np.diff(data["minimum_time"]))),
    float(data[0]["minimum_time"]),
    )
# Out:
# C:\Users\Bar1\AppData\Local\Temp\ipykernel_2064\1939064698.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data[0]["minimum_time"]),

# %%
oc.data
# Out:
#      minimum_time minimum_time_error weights minimum_type labels  cycle  \
# 0    2.460926e+06               None    None         None   None    1.0
# 1    2.460926e+06               None    None         None   None    1.0
# 2    2.460926e+06               None    None         None   None    1.0
# 3    2.460926e+06               None    None         None   None    1.0
# 4    2.460926e+06               None    None         None   None    1.0
# ..            ...                ...     ...          ...    ...    ...
# 195  2.460935e+06               None    None         None   None    1.0
# 196  2.460935e+06               None    None         None   None    1.0
# 197  2.460935e+06               None    None         None   None    1.0
# 198  2.460935e+06               None    None         None   None    1.0
# 199  2.460936e+06               None    None         None   None    1.0
#
#            oc
# 0   -0.050251
# 1    0.000000
# 2    0.050251
# 3    0.100503
# 4    0.150754
# ...

# %%
plt.plot(oc["cycle"], oc["oc"])

# %%
new_data = data.fill_errors(2)
new_weights = new_data.calculate_weights()

# %%
data.data.at[data.data.index[0], 'labels'] = "vis"
data.data
grouped_data = data.group_by("labels")
grouped_data[0].data
# Out:
#    minimum_time minimum_time_error weights minimum_type labels
# 0     2460925.5               None    None         None    vis

# %%
data.data.groupby("labels", dropna=True).groups
# Out:
# {'vis': [0]}
